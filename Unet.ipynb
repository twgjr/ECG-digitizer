# %%
# python standard
import os

# pytorch
import torch
from torch import nn
from torch.utils.data import DataLoader

# lightning
import lightning as L
from lightning.pytorch import seed_everything
from lightning.pytorch.callbacks.early_stopping import EarlyStopping
from lightning.pytorch.callbacks import ModelCheckpoint

# Project 
from data import *
from plotting import *
from models import *

# Constants
SEED = 654321
MAX_IMAGE_NUM = 21837

# %%
# set device variable to cuda or mps if available otherwise cpu
device = "cpu"
if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.cuda.empty_cache()
print(device)
# Out:
# cuda

# %%
seed_everything(SEED)
BATCH_SIZE = 16

def create_data_directory(path: str):
    if not os.path.exists(path):
        os.makedirs(path)

dir_lightning = os.path.join(".", "lightning", "unet")
create_data_directory(dir_lightning)
# Out:
# [rank: 0] Seed set to 654321

# %% [markdown]
# # Split the Data

# %% [markdown]
# Using the stratfold to seperate out the train, validation and test splits

# %%
ptbxl_database_df = pd.read_csv("../data/ptb_xl/ptbxl_database.csv")
img_set_df = ptbxl_database_df[['ecg_id', 'strat_fold']]


#define which folds to place in train-val-test sets
train_folds = [1] # 1-8
val_folds = [9] # always 9

# get train-val-test splits of ecg nums
train_id_list, val_id_list, _ = gen_splits(img_set_df, train_folds, val_folds, [])

print(f"train ID length: {len(train_id_list)}")
print(f"val ID length: {len(val_id_list)}")
# Out:
# train ID length: 2175
# val ID length: 2183

# %% [markdown]
# # Gather Input Data (Predictors)

# %% [markdown]
# Cannot use any images that have mismatching bounding boxes and wrong dimensions.  Must discard them from the dataset.  This is handled is proj_utils.py::get_X(). Unknown why the ecg generator is doing this.  The json is recording the correct dimensions but the actual image does not match, nor do the bounding boxes.  Future work.

# %%
X_train_df = get_X(train_id_list)
X_train_np = np.stack(X_train_df['img'])
X_train = torch.tensor(X_train_np ).float()
print(f"X_train shape {X_train.shape}")

X_val_df = get_X(val_id_list)
X_val_np = np.stack(X_val_df['img'])
X_val = torch.tensor(X_val_np ).float()
print(f"X_val shape {X_val.shape}")
# Out:
# X_train shape torch.Size([1091, 1, 425, 550])
# X_val shape torch.Size([1122, 1, 425, 550])

# %% [markdown]
# # Get the Outcome ECG waveforms

# %% [markdown]
# Building up the outcomes from left to right across the entire image for each lead.

# %%
y_train_np = get_outcomes(X_train_df, "I")
y_train = torch.tensor(y_train_np).float()
print(f"y_train shape: {y_train.shape}")

y_val_np= get_outcomes(X_val_df, "I")
y_val = torch.tensor(y_val_np).float()
print(f"y_val shape: {y_val.shape}")
# Out:
# y_train shape: torch.Size([1091, 5000])
# y_val shape: torch.Size([1122, 5000])

# %% [markdown]
# # Datasets

# %%
train_set = ECGDataSet(X_train, y_train)
print(f"train set shapes X:{train_set.x.shape}, y:{train_set.y.shape}")

val_set = ECGDataSet(X_val, y_val)
print(f"val set shapes X:{val_set.x.shape}, y:{val_set.y.shape}")
# Out:
# train set shapes X:torch.Size([1091, 1, 425, 550]), y:torch.Size([1091, 5000])
# val set shapes X:torch.Size([1122, 1, 425, 550]), y:torch.Size([1122, 5000])

# %% [markdown]
# # Data Loaders

# %%
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# # Full CNN Model

# %%
class Unet(nn.Module):
    def __init__(self, input_channels, initial_kernels, depth, kernel_size, desired_output_size=5000):
        super().__init__()
                
        # First convolution layer: Use 5000 kernels
        self.initial_conv = nn.Sequential(
            nn.Conv2d(input_channels, initial_kernels, kernel_size=kernel_size, padding=1),
            nn.BatchNorm2d(initial_kernels),
            nn.ReLU()
        )
        
        # First loop: double channels shrinking img dim
        self.conv_blocks = nn.ModuleList()
        in_channels = initial_kernels
        out_channels = initial_kernels * 2
        for i in range(depth):
            self.conv_blocks.append(
                nn.Sequential(
                    nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, padding=1),
                    nn.BatchNorm2d(out_channels),
                    nn.ReLU(),
                    nn.MaxPool2d(kernel_size=2)
                )
            )
            in_channels = out_channels
            out_channels *= 2  # Double the channels
                
        # Second loop: half channels growing back to original image dim
        in_channels = out_channels
        out_channels = out_channels // 2
        self.deconv_blocks = nn.ModuleList()
        for i in range(depth):
            self.deconv_blocks.append(
                nn.Sequential(
                    nn.ConvTranspose2d(in_channels, out_channels, kernel_size=1),
                    nn.BatchNorm2d(out_channels),
                    nn.ReLU()
                )
            )
            in_channels = out_channels
            out_channels = out_channels // 2
                
        # Fully connected layer to produce the desired output size
        self.fc = nn.Linear(in_channels, desired_output_size)

    def forward(self, x):
        # Pass through the initial convolution layer
        x = self.initial_conv(x)
        
        # Pass through the first loop
        for block in self.conv_blocks:
            x = block(x)
        
        # Pass through the second loop
        for block in self.deconv_blocks:
            x = block(x)
                
        # Flatten to (batch_size, in_channels)
        # x = x.view(x.size(0), -1)
        
        # # Pass through the FC layer for the desired output size
        # x = self.fc(x)
        return x


# Example Usage
input_channels = 1
initial_kernels = 128
depth = 2
dkernel_size=3
encoder = Unet(input_channels, initial_kernels, depth, kernel_size)

# Random input tensor of size (batch_size, channels, height, width)
input_tensor = torch.randn(1, input_channels, 425, 550)
output_features = encoder(input_tensor)

print("Input shape:", input_tensor.shape)
print("Output shape:", output_features.shape)
print("Output shape product:", np.prod(output_features.shape))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 75
#      73 # Random input tensor of size (batch_size, channels, height, width)
#      74 input_tensor = torch.randn(1, input_channels, 425, 550)
# ---> 75 output_features = encoder(input_tensor)
#      77 print("Input shape:", input_tensor.shape)
#      78 print("Output shape:", output_features.shape)
#
# File ~/.conda/envs/ecg/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/ecg/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[19], line 56, in Unet.forward(self, x)
#      54 # Pass through the second loop
#      55 for block in self.deconv_blocks:
# ---> 56     x = block(x)
#      58 # Flatten to (batch_size, in_channels)
#      59 # x = x.view(x.size(0), -1)
#      60
#      61 # # Pass through the FC layer for the desired output size
#      62 # x = self.fc(x)
#      63 return x
#
# File ~/.conda/envs/ecg/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/ecg/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.conda/envs/ecg/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/.conda/envs/ecg/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/ecg/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.conda/envs/ecg/lib/python3.12/site-packages/torch/nn/modules/conv.py:1162, in ConvTranspose2d.forward(self, input, output_size)
#    1151 num_spatial_dims = 2
#    1152 output_padding = self._output_padding(
#    1153     input,
#    1154     output_size,
#    (...)
#    1159     self.dilation,  # type: ignore[arg-type]
#    1160 )
# -> 1162 return F.conv_transpose2d(
#    1163     input,
#    1164     self.weight,
#    1165     self.bias,
#    1166     self.stride,
#    1167     self.padding,
#    1168     output_padding,
#    1169     self.groups,
#    1170     self.dilation,
#    1171 )
#
# RuntimeError: Given transposed=1, weight of size [1024, 512, 1, 1], expected input[1, 512, 106, 137] to have 1024 channels, but got 512 channels instead

# %%
class ECGDecoder(nn.Module):
    def __init__(self, input_dim, num_leads=12, num_lead_samples=5000):
        super().__init__()
        self.flatten = nn.Flatten()  # Flatten the input tensor
        self.linear1 = nn.Linear(input_dim, input_dim)
        self.linear2 = nn.Linear(input_dim, input_dim)
        self.relu = nn.ReLU()
        self.out = nn.Linear(input_dim, num_leads * num_lead_samples)  # Linear layer with 6000 output units
        
    def forward(self, x):
        x = self.flatten(x)  # Flatten the input tensor
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        x = self.relu(x)
        x = self.out(x)   # Pass through the linear layer
        return x

# Test the module with random input data
decoder = ECGDecoder(np.prod(output_features.shape), 1, 5000)
rslt = decoder(output_features)
print(f"Rslt shape: {rslt.shape}")
print(rslt.dtype)
# Out:
# Rslt shape: torch.Size([1, 5000])
# torch.float32

# %%
# seed_everything(SEED)
model_cnn = ECGRegressor(encoder, decoder)

# training
trainer = L.Trainer(default_root_dir=dir_lightning, 
                max_epochs=5,
                callbacks=[
                    EarlyStopping(monitor="val_loss_epoch_end", mode="min", patience=3),
                    ModelCheckpoint(
                         monitor='val_loss_epoch_end',
                         filename='ecg-cnn-{epoch:02d}-{val_loss:.2f}')],)

trainer.fit(model=model_cnn, train_dataloaders=train_loader, val_dataloaders=val_loader)
# Out:
# /home/twgreen/.conda/envs/ecg/lib/python3.12/site-packages/torchmetrics/utilities/prints.py:43: FutureWarning: The default value for `maximize` will be changed from `True` to `None` in v1.7.0 of TorchMetrics,will automatically infer the value based on the `higher_is_better` attribute of the metric (if such attribute exists) or raise an error if it does not. If you are explicitly setting the `maximize` argument to either `True` or `False` already, you can ignore this warning.
#   warnings.warn(*args, **kwargs)  # noqa: B028
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/twgreen/.conda/envs/ecg/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:75: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# You are using a CUDA device ('NVIDIA A100 80GB PCIe') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                 | Type          | Params | Mode
# ---------------------------------------------------------------
# 0 | loss                 | MSELoss       | 0      | train
# 1 | encoder              | DynamicCNN    | 1.6 M  | train
# 2 | decoder              | ECGDecoder    | 678 K  | train
# 3 | val_metrics_tracker  | MetricTracker | 0      | train
# 4 | test_metrics_tracker | MetricTracker | 0      | train
# ---------------------------------------------------------------
# 2.3 M     Trainable params
# 0         Non-trainable params
# 2.3 M     Total params
# 9.286     Total estimated model params size (MB)
# 43        Modules in train mode
# 0         Modules in eval mode
# SLURM auto-requeueing enabled. Setting signal handlers.
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/twgreen/.conda/envs/ecg/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /home/twgreen/.conda/envs/ecg/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 69/69 [00:20<00:00,  3.34it/s, v_num=1]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/71 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/71 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏         | 1/71 [00:00<00:00, 265.75it/s]
# Validation DataLoader 0:   3%|▎         | 2/71 [00:00<00:03, 18.86it/s]
# Validation DataLoader 0:   4%|▍         | 3/71 [00:00<00:04, 14.80it/s]
# Validation DataLoader 0:   6%|▌         | 4/71 [00:00<00:05, 12.32it/s]
# Validation DataLoader 0:   7%|▋         | 5/71 [00:00<00:05, 11.68it/s]
# Validation DataLoader 0:   8%|▊         | 6/71 [00:00<00:05, 11.07it/s]
# Validation DataLoader 0:  10%|▉         | 7/71 [00:00<00:05, 10.79it/s]
# Validation DataLoader 0:  11%|█▏        | 8/71 [00:00<00:05, 10.56it/s]
# Validation DataLoader 0:  59%|█████▉    | 42/71 [00:04<00:02,  9.86it/s]
# Validation DataLoader 0:  61%|██████    | 43/71 [00:04<00:02,  9.86it/s]
# Validation DataLoader 0:  62%|██████▏   | 44/71 [00:04<00:02,  9.85it/s]
# Validation DataLoader 0:  63%|██████▎   | 45/71 [00:04<00:02,  9.84it/s]
# Validation DataLoader 0:  65%|██████▍   | 46/71 [00:04<00:02,  9.83it/s]
# Validation DataLoader 0:  66%|██████▌   | 47/71 [00:04<00:02,  9.82it/s]
# Validation DataLoader 0:  68%|██████▊   | 48/71 [00:04<00:02,  9.81it/s]
# Validation DataLoader 0:  69%|██████▉   | 49/71 [00:04<00:02,  9.81it/s]
# Validation DataLoader 0:  70%|███████   | 50/71 [00:05<00:02,  9.80it/s]
# Validation DataLoader 0:  72%|███████▏  | 51/71 [00:05<00:02,  9.79it/s]
# Validation DataLoader 0:  73%|███████▎  | 52/71 [00:05<00:01,  9.78it/s]
# Validation DataLoader 0:  75%|███████▍  | 53/71 [00:05<00:01,  9.77it/s]
# Validation DataLoader 0:  76%|███████▌  | 54/71 [00:05<00:01,  9.78it/s]
# Validation DataLoader 0:  77%|███████▋  | 55/71 [00:05<00:01,  9.79it/s]
# Validation DataLoader 0:  79%|███████▉  | 56/71 [00:05<00:01,  9.80it/s]
# Validation DataLoader 0:  80%|████████  | 57/71 [00:05<00:01,  9.79it/s]
# Validation DataLoader 0:  82%|████████▏ | 58/71 [00:05<00:01,  9.79it/s]
# Validation DataLoader 0:  83%|████████▎ | 59/71 [00:06<00:01,  9.78it/s]
# Validation DataLoader 0:  85%|████████▍ | 60/71 [00:06<00:01,  9.77it/s]
# Validation DataLoader 0:  86%|████████▌ | 61/71 [00:06<00:01,  9.77it/s]
# Validation DataLoader 0:  87%|████████▋ | 62/71 [00:06<00:00,  9.76it/s]
# Validation DataLoader 0:  89%|████████▊ | 63/71 [00:06<00:00,  9.76it/s]
# Validation DataLoader 0:  90%|█████████ | 64/71 [00:06<00:00,  9.77it/s]
# Validation DataLoader 0:  92%|█████████▏| 65/71 [00:06<00:00,  9.78it/s]
# Validation DataLoader 0:  93%|█████████▎| 66/71 [00:06<00:00,  9.79it/s]
# Validation DataLoader 0:  94%|█████████▍| 67/71 [00:06<00:00,  9.77it/s]
# Validation DataLoader 0:  96%|█████████▌| 68/71 [00:06<00:00,  9.78it/s]
# Validation DataLoader 0:  97%|█████████▋| 69/71 [00:07<00:00,  9.77it/s]
# Validation DataLoader 0:  99%|█████████▊| 70/71 [00:07<00:00,  9.78it/s]
# Validation DataLoader 0: 100%|██████████| 71/71 [00:07<00:00,  9.79it/s]
# Epoch 4: 100%|██████████| 69/69 [00:27<00:00,  2.47it/s, v_num=1]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 69/69 [00:27<00:00,  2.47it/s, v_num=1]

# %%
plot_training_curves(model_cnn)

# %%
plot_signal_pred(model_cnn, None, val_set)
# Out:
# torch.Size([1, 5000])
# torch.Size([1, 5000])

# %%
targets = torch.cat(model_cnn.validation_step_targets)
outputs = torch.cat(model_cnn.validation_step_outputs)

plot_residuals(outputs, targets)
# Out:
# /home/twgreen/research/ECG-digitizer/plotting.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /home/twgreen/research/ECG-digitizer/plotting.py:32: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /home/twgreen/.conda/envs/ecg/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
